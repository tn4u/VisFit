# %% [markdown]
# # VisFit - Embedding Extraction
#
# This notebook contains a placeholder workflow for extracting embeddings from fashion images and text for recommendation experiments.

# %% [markdown]
# ## 1. Environment setup
#
# Install dependencies and import required libraries.

# %%
# !pip install -r ../requirements.txt
import os
import numpy as np
from PIL import Image

# %% [markdown]
# ## 2. Dataset path
#
# Set the raw dataset path and expected folders.

# %%
DATA_ROOT = "../data/raw"
PROCESSED_ROOT = "../data/processed"
os.makedirs(PROCESSED_ROOT, exist_ok=True)
print(f"Dataset root: {DATA_ROOT}")
print(f"Processed root: {PROCESSED_ROOT}")

# %% [markdown]
# ## 3. Embedding extraction placeholder
#
# Replace this section with the actual CLIP / transformer embedding extraction pipeline.

# %%
# Placeholder for embedding extraction
def extract_embeddings():
    """Placeholder for extracting image/text embeddings from the dataset."""
    raise NotImplementedError("Add the actual embedding extraction pipeline here.")

# %% [markdown]
# ## 4. Save embeddings placeholder
#
# Save computed vectors to `.npy` or `.npz` files under the processed data folder.

# %%
# Placeholder for saving embeddings
def save_embeddings(embeddings, output_path):
    """Save embedding vectors to a processed file."""
    np.save(output_path, embeddings)
    print(f"Saved embeddings to {output_path}")
